# %% [markdown]
# # FCT Unesp - TCC Treino 7
# Aluno: Pétrus Antonio Bárbosa Pradella
#
# TCC2 - Treinando análise preditiva para dados de transações comerciais.
#
# Teste 3
#     - DataSet Utilizado: Histórico de Chuva em Presidente Prudente
#     - Fonte: UNOESTE
#     - Link: https://www.udop.com.br/download/estatistica/economia_chuvas/1991a2019_historico_pprudente_ema_unoeste.pdf
#
# Caracteristicas gerais do Dataset:
#
#     - Número de Instancias: 9994
#     - Número de Atributos: 20

# %% [markdown]
# ### Importando as bibliotecas necessárias

# %%
from myownapi.AnalyticsARIMA import AnalyticsARIMA;

analytics  = AnalyticsARIMA();
# Out:
# '2.0.1z'

# %% [markdown]
# ### Carregando a base de dados

# %%
analytics.printIMGFromURL('https://i.imgur.com/PiT5Eb1.png');
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=760x576 at 0x249EDC94BA8>

# %%
onlineMode = False;

if onlineMode:
    dataset_folder_url = "http://downloads.finalcraft.com.br/tcc/UNOESTE";
else:
    dataset_folder_url = "C:/Users/Petrus/Desktop/UNESP/Docs 2016-2020/2019/Segundo Semestre/TCC2/TCC BigData Analytics/Treino7-Special";

dataset_file = dataset_folder_url + '/unoeste_historico_de_chuva.xls';

analytics.read_xls(dataset_file);
analytics.head(20)
# Out:
# Iniciando leitura do arquivo:
#  --> C:/Users/Petrus/Desktop/UNESP/Docs 2016-2020/2019/Segundo Semestre/TCC2/TCC BigData Analytics/Treino7-Special/unoeste_historico_de_chuva.xls
# Arquivo lido com sucesso!
#      Ano  Janeiro  Fevereiro  Março  Abril   Maio  Junho  Julho  Agosto  \
# 0   1991    180.7      197.9  174.0   90.3   15.4   93.4    7.2     0.0
# 1   1992     56.9      163.9  294.4  148.6  202.0   18.1   20.1    24.3
# 2   1993    119.9      338.4   83.0   51.0   67.0   41.0   14.6    38.0
# 3   1994    335.2      120.8  118.9   52.1   68.3   59.5   23.0     0.0
# 4   1995    198.2      245.6  106.0   64.2   66.4   54.0   22.2     0.0
# 5   1996    198.9      284.4  202.5  101.4   66.1    3.5    1.3    21.9
# 6   1997    304.5      187.7   33.0   53.3   77.8  237.9   17.9    17.1
# 7   1998    153.8       88.6  334.3  155.8   85.5    6.4    7.2   148.3
# 8   1999    195.0      315.1   46.3  132.8   60.2   48.2    7.6     0.0
# ...

# %% [markdown]
# ### Descrevendo o DataFrame

# %%
analytics.descreverDataFrame()
# Out:
#           Janeiro   Fevereiro       Março       Abril        Maio       Junho  \
# count   29.000000   29.000000   29.000000   29.000000   29.000000   29.000000
# mean   263.520690  206.313793  144.120690   86.879310   95.006897   59.027586
# std    140.071822  105.567831   77.975456   60.980145   68.488601   76.501704
# min     56.900000   24.700000   33.000000    0.000000   12.900000    0.000000
# 20%    148.360000  123.500000   84.380000   36.000000   39.060000   14.080000
# 40%    191.480000  175.420000  112.480000   55.280000   66.520000   34.240000
# 50%    198.900000  187.700000  118.900000   68.100000   71.600000   41.000000
# 60%    288.780000  199.900000  148.120000   90.120000   85.200000   47.900000
# 80%    397.100000  288.640000  202.700000  148.760000  140.960000   73.420000
# max    536.500000  509.600000  334.300000  250.400000  276.500000  372.400000
#
#             Julho      Agosto    Setembro     Outubro    Novembro    Dezembro
# ...

# %%
analytics.plotarSimple('Julho')

# %%
for columName in list(analytics.df.columns):
    analytics.tratarVariaveisNulasComMediaDasOutras(columName);
# Out:
# Nenhum valor nulo foi encontrado na coluna: Ano
# Nenhum valor nulo foi encontrado na coluna: Janeiro
# Nenhum valor nulo foi encontrado na coluna: Fevereiro
# Nenhum valor nulo foi encontrado na coluna: Março
# Nenhum valor nulo foi encontrado na coluna: Abril
# Nenhum valor nulo foi encontrado na coluna: Maio
# Nenhum valor nulo foi encontrado na coluna: Junho
# Nenhum valor nulo foi encontrado na coluna: Julho
# Nenhum valor nulo foi encontrado na coluna: Agosto
# Nenhum valor nulo foi encontrado na coluna: Setembro
# Nenhum valor nulo foi encontrado na coluna: Outubro
# Nenhum valor nulo foi encontrado na coluna: Novembro
# Nenhum valor nulo foi encontrado na coluna: Dezembro

# %% [markdown]
# ### Tratando o DataSet

# %%
import pandas as pd

def toDate(year, month):
    dateString = "{}-1-{}".format(month,int(year));
    return pd.to_datetime(dateString);

df = pd.DataFrame({"Data":[], "Precipitacao":[]}) 

for index, row in analytics.df.iterrows():
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],1)], "Precipitacao":[row['Janeiro']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],2)], "Precipitacao":[row['Fevereiro']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],3)], "Precipitacao":[row['Março']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],4)], "Precipitacao":[row['Abril']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],5)], "Precipitacao":[row['Maio']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],6)], "Precipitacao":[row['Junho']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],7)], "Precipitacao":[row['Julho']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],8)], "Precipitacao":[row['Agosto']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],9)], "Precipitacao":[row['Setembro']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],10)], "Precipitacao":[row['Outubro']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],11)], "Precipitacao":[row['Novembro']]}), ignore_index=True);
    df = df.append(pd.DataFrame({"Data":[toDate(row['Ano'],12)], "Precipitacao":[row['Dezembro']]}), ignore_index=True);
        
analytics.setDataframe(df);
print(df)
# Out:
#           Data  Precipitacao
# 0   1991-01-01         180.7
# 1   1991-02-01         197.9
# 2   1991-03-01         174.0
# 3   1991-04-01          90.3
# 4   1991-05-01          15.4
# 5   1991-06-01          93.4
# 6   1991-07-01           7.2
# 7   1991-08-01           0.0
# 8   1991-09-01          14.9
# 9   1991-10-01         153.0
# 10  1991-11-01         136.0
# 11  1991-12-01         539.6
# 12  1992-01-01          56.9
# 13  1992-02-01         163.9
# 14  1992-03-01         294.4
# 15  1992-04-01         148.6
# 16  1992-05-01         202.0
# 17  1992-06-01          18.1
# 18  1992-07-01          20.1
# 19  1992-08-01          24.3
# 20  1992-09-01         215.2
# 21  1992-10-01         153.0
# 22  1992-11-01         102.1
# 23  1992-12-01          56.5
# 24  1993-01-01         119.9
# 25  1993-02-01         338.4
# 26  1993-03-01          83.0
# 27  1993-04-01          51.0
# 28  1993-05-01          67.0
# 29  1993-06-01          41.0
# ..         ...           ...
# ...

# %%
analytics.descreverAtributo('Data')
# Out:
# count                     348
# unique                    348
# top       2009-09-01 00:00:00
# freq                        1
# first     1991-01-01 00:00:00
# last      2019-12-01 00:00:00
# Name: Data, dtype: object

# %% [markdown]
# ### Selecionando dados

# %%
#Reduzindo dataset para apenas um valor, sendo a data ao INDEX
result = analytics.pegarDataframeAgrupadoPor('Data', 'Precipitacao', replaceInside=True);
print(result)
# Out:
#             Precipitacao
# Data
# 1991-01-01         180.7
# 1991-02-01         197.9
# 1991-03-01         174.0
# 1991-04-01          90.3
# 1991-05-01          15.4
# 1991-06-01          93.4
# 1991-07-01           7.2
# 1991-08-01           0.0
# 1991-09-01          14.9
# 1991-10-01         153.0
# 1991-11-01         136.0
# 1991-12-01         539.6
# 1992-01-01          56.9
# 1992-02-01         163.9
# 1992-03-01         294.4
# 1992-04-01         148.6
# 1992-05-01         202.0
# 1992-06-01          18.1
# 1992-07-01          20.1
# 1992-08-01          24.3
# 1992-09-01         215.2
# 1992-10-01         153.0
# 1992-11-01         102.1
# 1992-12-01          56.5
# 1993-01-01         119.9
# 1993-02-01         338.4
# 1993-03-01          83.0
# 1993-04-01          51.0
# 1993-05-01          67.0
# 1993-06-01          41.0
# ...                  ...
# 2017-07-01           0.0
# 2017-08-01          74.0
# 2017-09-01          16.3
# 2017-10-01         258.0
# ...

# %% [markdown]
# ### Visualização dos Dados

# %%
analytics.plotarSelf();

# %%
analytics.plotarSimpleSelf(theFigsize=(16,6));

# %%
analytics.plotarDecomposicao(theFigsize=(16,6));

# %% [markdown]
# ### Arima Predction

# %%
analytics.aplicarARIMA(verbose=True);
# Out:
# # ==============================================================================================================
# # Preparando quantidade de treino.
# # ==============================================================================================================
#
#
# [(0, 0, 0, 12), (0, 0, 1, 12), (0, 1, 0, 12), (0, 1, 1, 12), (1, 0, 0, 12), (1, 0, 1, 12), (1, 1, 0, 12), (1, 1, 1, 12)]
# # ==============================================================================================================
# # Escolhendo a melhor combinação de parametros arima.
# # ==============================================================================================================
#
#
# ARIMA(0, 0, 0)x(0, 0, 0, 12)x12 - AIC:4549.861806746507
# ARIMA(0, 0, 0)x(0, 0, 1, 12)x12 - AIC:4270.123103739472
# ARIMA(0, 0, 0)x(0, 1, 0, 12)x12 - AIC:4196.8195572840705
# ARIMA(0, 0, 0)x(0, 1, 1, 12)x12 - AIC:3833.93641567575
# ARIMA(0, 0, 0)x(1, 0, 0, 12)x12 - AIC:4154.9757469219585
# ...

# %% [markdown]
# #### Observação de Diagnóstico

# %%
analytics.diagnostico()

# %% [markdown]
# ### Forecast dos dados em modo de treino

# %%
analytics.ARIMAPrediction()

# %%
analytics.ARIMAPrediction(forecastStartingDate = '2018', datasetStartDate = '2015')

# %% [markdown]
# ### Real Forecast

# %%
analytics.ARIMAForecast(24, verbose = True)
# Out:
# 2020-01-01    253.931529
# 2020-02-01    194.117514
# 2020-03-01    131.934699
# 2020-04-01     74.700814
# 2020-05-01     82.814836
# 2020-06-01     46.844010
# 2020-07-01     35.203632
# 2020-08-01     28.138573
# 2020-09-01     84.978491
# 2020-10-01    138.359087
# 2020-11-01    143.064232
# 2020-12-01    196.252616
# 2021-01-01    253.849918
# 2021-02-01    194.035904
# 2021-03-01    131.853089
# 2021-04-01     74.619204
# 2021-05-01     82.733225
# 2021-06-01     46.762400
# 2021-07-01     35.122022
# 2021-08-01     28.056963
# 2021-09-01     84.896881
# 2021-10-01    138.277476
# 2021-11-01    142.982622
# 2021-12-01    196.171006
# Freq: MS, dtype: float64

# %%
analytics.ARIMAForecast(24, verbose = True, datasetStartDate = '2017')
# Out:
# 2020-01-01    253.931529
# 2020-02-01    194.117514
# 2020-03-01    131.934699
# 2020-04-01     74.700814
# 2020-05-01     82.814836
# 2020-06-01     46.844010
# 2020-07-01     35.203632
# 2020-08-01     28.138573
# 2020-09-01     84.978491
# 2020-10-01    138.359087
# 2020-11-01    143.064232
# 2020-12-01    196.252616
# 2021-01-01    253.849918
# 2021-02-01    194.035904
# 2021-03-01    131.853089
# 2021-04-01     74.619204
# 2021-05-01     82.733225
# 2021-06-01     46.762400
# 2021-07-01     35.122022
# 2021-08-01     28.056963
# 2021-09-01     84.896881
# 2021-10-01    138.277476
# 2021-11-01    142.982622
# 2021-12-01    196.171006
# Freq: MS, dtype: float64
